# %%
import pandas as pd

# %%
price_1 = pd.read_csv("ROUND1_data/prices_round_1_day_-2.csv", sep = ';', header = 0)
price_2 = pd.read_csv("ROUND1_data/prices_round_1_day_-1.csv", sep = ';', header = 0)
price_3 = pd.read_csv("ROUND1_data/prices_round_1_day_0.csv", sep = ';', header = 0)

# %%
ash_1 = price_1[price_1["product"] == "ASH_COATED_OSMIUM"]
pepper_1 = price_2[price_2["product"] == "INTARIAN_PEPPER_ROOT"]

ash_2 = price_2[price_2["product"] == "ASH_COATED_OSMIUM"]
pepper_2 = price_2[price_2["product"] == "INTARIAN_PEPPER_ROOT"]

ash_3 = price_3[price_3["product"] == "ASH_COATED_OSMIUM"]
pepper_3 = price_3[price_3["product"] == "INTARIAN_PEPPER_ROOT"]

# %%
ash_1
# Out:
#        day  timestamp            product  bid_price_1  bid_volume_1  \
# 1       -2          0  ASH_COATED_OSMIUM          NaN           NaN
# 3       -2        100  ASH_COATED_OSMIUM       9992.0          15.0
# 5       -2        200  ASH_COATED_OSMIUM       9992.0          15.0
# 6       -2        300  ASH_COATED_OSMIUM       9992.0          13.0
# 8       -2        400  ASH_COATED_OSMIUM       9992.0          15.0
# ...    ...        ...                ...          ...           ...
# 19990   -2     999500  ASH_COATED_OSMIUM       9984.0          13.0
# 19992   -2     999600  ASH_COATED_OSMIUM       9984.0          15.0
# 19995   -2     999700  ASH_COATED_OSMIUM       9984.0          10.0
# 19997   -2     999800  ASH_COATED_OSMIUM       9984.0          14.0
# 19999   -2     999900  ASH_COATED_OSMIUM       9984.0          13.0
#
#        bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 1              NaN           NaN          NaN           NaN      10010.0
# ...

# %%
ash_2
# Out:
#        day  timestamp            product  bid_price_1  bid_volume_1  \
# 1       -1          0  ASH_COATED_OSMIUM          NaN           NaN
# 2       -1        100  ASH_COATED_OSMIUM       9984.0          11.0
# 4       -1        200  ASH_COATED_OSMIUM       9985.0          15.0
# 7       -1        300  ASH_COATED_OSMIUM       9985.0          11.0
# 9       -1        400  ASH_COATED_OSMIUM       9985.0          12.0
# ...    ...        ...                ...          ...           ...
# 19990   -1     999500  ASH_COATED_OSMIUM       9992.0          29.0
# 19993   -1     999600  ASH_COATED_OSMIUM       9994.0          14.0
# 19994   -1     999700  ASH_COATED_OSMIUM       9994.0          12.0
# 19997   -1     999800  ASH_COATED_OSMIUM       9994.0          13.0
# 19998   -1     999900  ASH_COATED_OSMIUM       9994.0          10.0
#
#        bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 1              NaN           NaN          NaN           NaN      10003.0
# ...

# %%
pepper_1
# Out:
#        day  timestamp               product  bid_price_1  bid_volume_1  \
# 0       -1          0  INTARIAN_PEPPER_ROOT      10991.0          15.0
# 3       -1        100  INTARIAN_PEPPER_ROOT      10994.0           9.0
# 5       -1        200  INTARIAN_PEPPER_ROOT      10994.0          10.0
# 6       -1        300  INTARIAN_PEPPER_ROOT          NaN           NaN
# 8       -1        400  INTARIAN_PEPPER_ROOT      10992.0          20.0
# ...    ...        ...                   ...          ...           ...
# 19991   -1     999500  INTARIAN_PEPPER_ROOT      11993.0           8.0
# 19992   -1     999600  INTARIAN_PEPPER_ROOT          NaN           NaN
# 19995   -1     999700  INTARIAN_PEPPER_ROOT      11993.0          10.0
# 19996   -1     999800  INTARIAN_PEPPER_ROOT      11993.0          12.0
# 19999   -1     999900  INTARIAN_PEPPER_ROOT      11990.0          25.0
#
#        bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# ...

# %%
pepper_2
# Out:
#        day  timestamp               product  bid_price_1  bid_volume_1  \
# 0       -1          0  INTARIAN_PEPPER_ROOT      10991.0          15.0
# 3       -1        100  INTARIAN_PEPPER_ROOT      10994.0           9.0
# 5       -1        200  INTARIAN_PEPPER_ROOT      10994.0          10.0
# 6       -1        300  INTARIAN_PEPPER_ROOT          NaN           NaN
# 8       -1        400  INTARIAN_PEPPER_ROOT      10992.0          20.0
# ...    ...        ...                   ...          ...           ...
# 19991   -1     999500  INTARIAN_PEPPER_ROOT      11993.0           8.0
# 19992   -1     999600  INTARIAN_PEPPER_ROOT          NaN           NaN
# 19995   -1     999700  INTARIAN_PEPPER_ROOT      11993.0          10.0
# 19996   -1     999800  INTARIAN_PEPPER_ROOT      11993.0          12.0
# 19999   -1     999900  INTARIAN_PEPPER_ROOT      11990.0          25.0
#
#        bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# ...
